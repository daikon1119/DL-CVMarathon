# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
# import tensorflow as tf
# print(tf.__version__)

# import os
# from google.colab import drive 
# drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING:tensorflow:From /Users/aliceliao/opt/anaconda3/envs/DL-CVMarathon/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /Users/aliceliao/opt/anaconda3/envs/DL-CVMarathon/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
# 印出網路結構
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=10, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# WARNING:tensorflow:From /Users/aliceliao/opt/anaconda3/envs/DL-CVMarathon/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 1712 samples, validate on 428 samples
# Epoch 1/10
# 1712/1712 [==============================] - 4s 3ms/step - loss: 0.0058 - val_loss: 0.0021
#
# Epoch 00001: val_loss improved from inf to 0.00212, saving model to best_weights.h5
# Epoch 2/10
# 1712/1712 [==============================] - 4s 2ms/step - loss: 0.0015 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00212 to 0.00193, saving model to best_weights.h5
# Epoch 3/10
# 1712/1712 [==============================] - 4s 2ms/step - loss: 0.0013 - val_loss: 0.0019
#
# Epoch 00003: val_loss improved from 0.00193 to 0.00193, saving model to best_weights.h5
# Epoch 4/10
# 1712/1712 [==============================] - 4s 2ms/step - loss: 0.0012 - val_loss: 0.0019
#
# Epoch 00004: val_loss improved from 0.00193 to 0.00190, saving model to best_weights.h5
# Epoch 5/10
# 1712/1712 [==============================] - 4s 2ms/step - loss: 0.0011 - val_loss: 0.0019
#
# Epoch 00005: val_loss improved from 0.00190 to 0.00189, saving model to best_weights.h5
# Epoch 6/10
# 1712/1712 [==============================] - 4s 2ms/step - loss: 0.0011 - val_loss: 0.0019
#
# Epoch 00006: val_loss improved from 0.00189 to 0.00187, saving model to best_weights.h5
# Epoch 7/10
# 1712/1712 [==============================] - 4s 2ms/step - loss: 9.6422e-04 - val_loss: 0.0018
#
# Epoch 00007: val_loss improved from 0.00187 to 0.00181, saving model to best_weights.h5
# Epoch 8/10
# 1712/1712 [==============================] - 4s 2ms/step - loss: 8.4955e-04 - val_loss: 0.0016
#
# Epoch 00008: val_loss improved from 0.00181 to 0.00163, saving model to best_weights.h5
# Epoch 9/10
# 1712/1712 [==============================] - 4s 2ms/step - loss: 7.5649e-04 - val_loss: 0.0015
#
# Epoch 00009: val_loss improved from 0.00163 to 0.00152, saving model to best_weights.h5
# Epoch 10/10
# 1712/1712 [==============================] - 4s 2ms/step - loss: 6.6517e-04 - val_loss: 0.0014
#
# Epoch 00010: val_loss improved from 0.00152 to 0.00137, saving model to best_weights.h5

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Your code
img_flips=[]
point_flip=[]
point_flips=[]
for i in range(imgs_train.shape[0]):
    img_flip = np.flip(imgs_train[i], 1)
    img_flips.append(img_flip)

for i in range(points_train.shape[0]):
    for j in range(0, 30, 2):
        x = -points_train[i][j]
        y = points_train[i][j+1]
        point_flip.append(x)
        point_flip.append(y)
    
point_flips.append(point_flip)
point_flips=np.array(point_flips).reshape(points_train.shape[0], 30)

#adjust index
for i in range(point_flips.shape[0]):
    point_flips_temp=np.copy(point_flips[i])
    point_flips[i][0:2]=point_flips_temp[2:4]
    point_flips[i][2:4]=point_flips_temp[0:2]
    point_flips[i][4:6]=point_flips_temp[8:10]
    point_flips[i][6:8]=point_flips_temp[10:12]
    point_flips[i][8:10]=point_flips_temp[4:6]
    point_flips[i][10:12]=point_flips_temp[6:8]
    point_flips[i][12:14]=point_flips_temp[16:18]
    point_flips[i][14:16]=point_flips_temp[18:20]
    point_flips[i][16:18]=point_flips_temp[12:14]
    point_flips[i][18:20]=point_flips_temp[14:16]
    #point_flips[20:22]=point_flips_temp[]
    point_flips[i][22:24]=point_flips_temp[24:26]
    point_flips[i][24:26]=point_flips_temp[22:24]
    #point_flips[26:28]=point_flips_temp[]
    #point_flips[28:30]=point_flips_temp[]


point_flips=point_flips.tolist()

for i in range(imgs_train.shape[0]):
    img_flips.append(imgs_train[i])

for i in range(points_train.shape[0]):
    point_flips.append(points_train[i])
    
img_flips=np.array(img_flips)
point_flips=np.array(point_flips)



print(img_flips.shape)
print(point_flips.shape)

# model checkpoint 
checkpoint_aug = ModelCheckpoint('best_weights_augment.h5', verbose=1, save_best_only=True)
# training the model
hist_model_aug = model_with_augment.fit(img_flips.reshape(img_flips.shape[0], 96, 96, 1), 
                       point_flips, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint_aug, hist],
                       shuffle=True, epochs=10, verbose=1)
# Out:
# (4280, 96, 96)
# (4280, 30)
# Train on 3424 samples, validate on 856 samples
# Epoch 1/10
# 3424/3424 [==============================] - 9s 3ms/step - loss: 0.0020 - val_loss: 0.0011
#
# Epoch 00001: val_loss improved from inf to 0.00106, saving model to best_weights_augment.h5
# Epoch 2/10
# 3424/3424 [==============================] - 9s 3ms/step - loss: 6.0515e-04 - val_loss: 8.3330e-04
#
# Epoch 00002: val_loss improved from 0.00106 to 0.00083, saving model to best_weights_augment.h5
# Epoch 3/10
# 3424/3424 [==============================] - 9s 3ms/step - loss: 5.1439e-04 - val_loss: 7.3895e-04
#
# Epoch 00003: val_loss improved from 0.00083 to 0.00074, saving model to best_weights_augment.h5
# Epoch 4/10
# 3424/3424 [==============================] - 9s 3ms/step - loss: 4.6742e-04 - val_loss: 7.1982e-04
#
# Epoch 00004: val_loss improved from 0.00074 to 0.00072, saving model to best_weights_augment.h5
# Epoch 5/10
# 3424/3424 [==============================] - 9s 3ms/step - loss: 4.3288e-04 - val_loss: 7.0288e-04
#
# Epoch 00005: val_loss improved from 0.00072 to 0.00070, saving model to best_weights_augment.h5
# Epoch 6/10
# 3424/3424 [==============================] - 9s 3ms/step - loss: 3.9573e-04 - val_loss: 5.9689e-04
#
# Epoch 00006: val_loss improved from 0.00070 to 0.00060, saving model to best_weights_augment.h5
# Epoch 7/10
# 3424/3424 [==============================] - 9s 3ms/step - loss: 3.7917e-04 - val_loss: 5.7381e-04
#
# Epoch 00007: val_loss improved from 0.00060 to 0.00057, saving model to best_weights_augment.h5
# Epoch 8/10
# 2496/3424 [====================>.........] - ETA: 2s - loss: 3.6902e-04

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 3, 1, xticks=[], yticks=[])
plot_keypoints(imgs_train[0], points_train[0]) # 原來的圖片
ax = fig.add_subplot(1, 3, 2, xticks=[], yticks=[])
plot_keypoints(img_flips[0], point_flips[0]) # 翻轉後的圖片
ax = fig.add_subplot(1, 3, 3, xticks=[], yticks=[])
plot_keypoints(img_flips[2140], point_flips[2140]) # 原來的圖片

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model_aug.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model_aug.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')
